# %% [markdown]
# ## Loading Data using pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('pokemon_data.csv')

# %%
df.head(5) #prints the first 5 rows
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(5) #prints the last 5 rows
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ### Loading text data with comma separated text

# %%
df_txt=pd.read_csv('pokemon_data.csv',delimiter=',')

# %%
df_txt.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Reading Data

# %%
df.columns #reading headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name'] #reading each column
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Name','Type 2','HP']] #reading multiple columns
# Out:
#                       Name  Type 2  HP
# 0                Bulbasaur  Poison  45
# 1                  Ivysaur  Poison  60
# 2                 Venusaur  Poison  80
# 3    VenusaurMega Venusaur  Poison  80
# 4               Charmander     NaN  39
# ..                     ...     ...  ..
# 795                Diancie   Fairy  50
# 796    DiancieMega Diancie   Fairy  50
# 797    HoopaHoopa Confined   Ghost  80
# 798     HoopaHoopa Unbound    Dark  80
# 799              Volcanion   Water  80
#
# [800 rows x 3 columns]

# %%
df[['Name','Type 2','HP']][0:6] #reading multiple columns from row 0 to row 5
# Out:
#                     Name  Type 2  HP
# 0              Bulbasaur  Poison  45
# 1                Ivysaur  Poison  60
# 2               Venusaur  Poison  80
# 3  VenusaurMega Venusaur  Poison  80
# 4             Charmander     NaN  39
# 5             Charmeleon     NaN  58

# %%
df.iloc[0] #reading row 0
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
df.iloc[796:] #reading multiple rows
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.iloc[799,1] #reading object at a specific position
# Out:
# 'Volcanion'

# %%
df.loc[df['Type 1']=='Psychic'] #reading specific row entities
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 68    63                     Abra  Psychic       NaN   25      20       15
# 69    64                  Kadabra  Psychic       NaN   40      35       30
# 70    65                 Alakazam  Psychic       NaN   55      50       45
# 71    65    AlakazamMega Alakazam  Psychic       NaN   55      50       65
# 104   96                  Drowzee  Psychic       NaN   60      48       45
# 105   97                    Hypno  Psychic       NaN   85      73       70
# 131  122                 Mr. Mime  Psychic     Fairy   40      45       65
# 162  150                   Mewtwo  Psychic       NaN  106     110       90
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150      MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 165  151                      Mew  Psychic       NaN  100     100      100
# ...
